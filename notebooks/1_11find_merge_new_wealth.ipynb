# %%
import os
import openpyxl
import re
import csv
import os
import pandas as pd

# %%
def  add_new_wealth (input_file,output_file):
# this function is to add the median income of the property's current sa2 area in to the data collection
# this is mannually fill in with some of the missing sa2 area 
# input_file: the csv file needed to add in more features 
# output_file: is the csv name and the output path of the merged/adjusted csv file
    workbook = openpyxl.load_workbook('../data/landing/new_wealth/new_wealth_data.xlsx')
    sheet=workbook["Table 1.4"]
    matching_rows = []
    pattern = re.compile(r'2\d{8}$')
    row_iterator= sheet.iter_rows(values_only=True)
    for i in range(8):
        next (row_iterator)
    for row  in row_iterator:
        code_value = str(row[0])
        if pattern.match(code_value):
            matching_rows.append(row)
    value_list=[]
    for i in matching_rows:
        value_list.append([i[0],i[21],i[26]]) 
    column_names = ["Sa2_code","median_2019_2020","mean_2019_20"]
    df = pd.DataFrame(value_list, columns=column_names)
    newrow = [{"Sa2_code":201011481,"median_2019_2020":53784,"mean_2019_20":77876},
              {"Sa2_code":203021486,"median_2019_2020":45160,"mean_2019_20":49113},
              {"Sa2_code":203021487,"median_2019_2020":51437,"mean_2019_20":58771},
              {"Sa2_code":203021488,"median_2019_2020":45160,"mean_2019_20":49113},
              {"Sa2_code":205041493,"median_2019_2020":55464,"mean_2019_20":67111},
              {"Sa2_code":205041494,"median_2019_2020":55464,"mean_2019_20":67111},
              {"Sa2_code":206011495,"median_2019_2020":60295,"mean_2019_20":72244},
              {"Sa2_code":206011496,"median_2019_2020":60295,"mean_2019_20":72244},
              {"Sa2_code":206041506,"median_2019_2020":51142,"mean_2019_20":68952},
              {"Sa2_code":206041508,"median_2019_2020":52625,"mean_2019_20":74293},
              {"Sa2_code":206041509,"median_2019_2020":52625,"mean_2019_20":74293},
              {"Sa2_code":206041510,"median_2019_2020":90927,"mean_2019_20":107532},
              {"Sa2_code":206071517,"median_2019_2020":73100,"mean_2019_20":91342},
              {"Sa2_code":206071518,"median_2019_2020":73100,"mean_2019_20":91342},
              {"Sa2_code":207011519,"median_2019_2020":60787,"mean_2019_20":105348},
              {"Sa2_code":207011520,"median_2019_2020":60787,"mean_2019_20":105348},
              {"Sa2_code":207011521,"median_2019_2020":64352,"mean_2019_20":110615},
              {"Sa2_code":207011522,"median_2019_2020":64352,"mean_2019_20":110615},
              {"Sa2_code":209041529,"median_2019_2020":45028,"mean_2019_20":51052},
              {"Sa2_code":209041530,"median_2019_2020":45028,"mean_2019_20":51052},
              {"Sa2_code":209041531,"median_2019_2020":55196,"mean_2019_20":62279},
              {"Sa2_code":206051511,"median_2019_2020":78187,"mean_2019_20":108763},
              {"Sa2_code":206051512,"median_2019_2020":68507,"mean_2019_20":98526},
              {"Sa2_code":206051513,"median_2019_2020":60080,"mean_2019_20":79087},
              {"Sa2_code":206051514,"median_2019_2020":60080,"mean_2019_20":79087},
              {"Sa2_code":206061515,"median_2019_2020":69578,"mean_2019_20":114590},
              {"Sa2_code":206061516,"median_2019_2020":69578,"mean_2019_20":114590},
              {"Sa2_code":209021523,"median_2019_2020":49563,"mean_2019_20":53779},
              {"Sa2_code":209021524,"median_2019_2020":50457,"mean_2019_20":57143},
              {"Sa2_code":209021525,"median_2019_2020":49563,"mean_2019_20":53779},
              {"Sa2_code":209021526,"median_2019_2020":50457,"mean_2019_20":57143},
              {"Sa2_code":203031489,"median_2019_2020":53827,"mean_2019_20":68008},
              {"Sa2_code":203031490,"median_2019_2020":53827,"mean_2019_20":68008},
              {"Sa2_code":206011497,"median_2019_2020":56209,"mean_2019_20":69015},
              {"Sa2_code":206011498,"median_2019_2020":56209,"mean_2019_20":69015},
              {"Sa2_code":206021499,"median_2019_2020":66562,"mean_2019_20":86353},
              {"Sa2_code":206021500,"median_2019_2020":66562,"mean_2019_20":86353},
              {"Sa2_code":206031501,"median_2019_2020":62800,"mean_2019_20":85058},
              {"Sa2_code":206031502,"median_2019_2020":62800,"mean_2019_20":85058},
              {"Sa2_code":212011548,"median_2019_2020":50247,"mean_2019_20":57344},
              {"Sa2_code":212011549,"median_2019_2020":50678,"mean_2019_20":50678},
              {"Sa2_code":212011552,"median_2019_2020":50678,"mean_2019_20":55753},
              {"Sa2_code":212041563,"median_2019_2020":45310,"mean_2019_20":50653},
              {"Sa2_code":212041563,"median_2019_2020":41556,"mean_2019_20":47670},
              {"Sa2_code":212051567,"median_2019_2020":33358,"mean_2019_20":44648},
              {"Sa2_code":212051568,"median_2019_2020":33358,"mean_2019_20":44648},
              {"Sa2_code":214021592,"median_2019_2020":48663,"mean_2019_20":63266},
              {"Sa2_code":210031538,"median_2019_2020":60198,"mean_2019_20":69303},
              {"Sa2_code":210011534,"median_2019_2020":55357,"mean_2019_20":67614},
              {"Sa2_code":210031535,"median_2019_2020":47123,"mean_2019_20":52923},
              {"Sa2_code":210031536,"median_2019_2020":47123,"mean_2019_20":52923},
              {"Sa2_code":210041540,"median_2019_2020":56607,"mean_2019_20":62355},
              {"Sa2_code":210041541,"median_2019_2020":56488,"mean_2019_20":66106}
                    ]
    df = df.append(newrow, ignore_index=True)
    input_data = pd.read_csv(input_file)
    value_1_list=[]
    value_2_list=[]
    for count in range(len(input_data)):
        sa2_code = input_data["SA2_code"][count]
        
        matched=False 
        
        for value_count in range(len(df)):
            value_sa2_code = df["Sa2_code"][value_count]
            if sa2_code==value_sa2_code:
                matched= True
                value_1=df["median_2019_2020"][value_count]
                value_2=df["mean_2019_20"][value_count]
            if matched:
                if value_1=="-":
                    value_1_list.append("51996")
                else:
                    value_1_list.append(value_1)
                if value_2=="-":
                    value_2_list.append("51,996")
                else:
                    value_2_list.append(value_2)
                break

        if not matched:
            value_1_list.append("51,996")
            value_2_list.append("51,996")
    input_data["median_2019_2020"]=value_1_list
    input_data["mean_2019_2020"]=value_2_list
    if not os.path.exists("../data/curated/tenth_clean"):
        os.makedirs("../data/curated/tenth_clean")
    input_data.to_csv(output_file,index=False )

# %%
add_new_wealth("../data/curated/ninth_clean/apartment_1.csv","../data/curated/tenth_clean/apartment_1.csv")
add_new_wealth("../data/curated/ninth_clean/apartment_2.csv","../data/curated/tenth_clean/apartment_2.csv")
add_new_wealth("../data/curated/ninth_clean/apartment_3.csv","../data/curated/tenth_clean/apartment_3.csv")
add_new_wealth("../data/curated/ninth_clean/apartment_4.csv","../data/curated/tenth_clean/apartment_4.csv")
add_new_wealth("../data/curated/ninth_clean/apartment_5.csv","../data/curated/tenth_clean/apartment_5.csv")

add_new_wealth("../data/curated/ninth_clean/house_1.csv","../data/curated/tenth_clean/house_1.csv")  
add_new_wealth("../data/curated/ninth_clean/house_2.csv","../data/curated/tenth_clean/house_2.csv")  
add_new_wealth("../data/curated/ninth_clean/house_3.csv","../data/curated/tenth_clean/house_3.csv")  
add_new_wealth("../data/curated/ninth_clean/house_4.csv","../data/curated/tenth_clean/house_4.csv")  

add_new_wealth("../data/curated/ninth_clean/town_house.csv","../data/curated/tenth_clean/town_house.csv")
# Out:
# /var/folders/gf/by74yth12b961jz2g6yc7rs40000gn/T/ipykernel_33536/3470406428.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newrow, ignore_index=True)
# /var/folders/gf/by74yth12b961jz2g6yc7rs40000gn/T/ipykernel_33536/3470406428.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newrow, ignore_index=True)
# /var/folders/gf/by74yth12b961jz2g6yc7rs40000gn/T/ipykernel_33536/3470406428.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newrow, ignore_index=True)
# ...
